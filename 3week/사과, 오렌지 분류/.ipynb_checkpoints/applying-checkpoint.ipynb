# %%
import os


train_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/train')
validation_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/validation')

# 훈련에 사용되는 사과/오렌지 이미지 경로
train_apple_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/train/apple')
train_orange_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/train/orange')

print(train_apple_dir)
print(train_orange_dir)

# 테스트에 사용되는 사과/오렌지 이미지 경로
validation_apple_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/validation/apple')
validation_orange_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/validation/apple')

print(validation_apple_dir)
print(validation_orange_dir)
# Out:
# C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/train/apple
# C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/train/orange
# C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/validation/apple
# C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/validation/apple

# %%
train_apple_fnames = os.listdir(train_apple_dir)
train_orange_fnames = os.listdir(train_orange_dir)

print(train_apple_fnames[:5])
print(train_orange_fnames[:5])
# Out:
# ['사진 다운로드0.jpg', '사진 다운로드1.jpg', '사진 다운로드2.jpg', '사진 다운로드3.jpg', '사진 다운로드4.jpg']
# ['사진 다운로드0.jpg', '사진 다운로드1.jpg', '사진 다운로드2.jpg', '사진 다운로드3.jpg', '사진 다운로드4.jpg']

# %%
print('Total training apple images :', len(os.listdir(train_apple_dir)))
print('Total training orange images :', len(os.listdir(train_orange_dir)))

print('Total validation apple images :', len(os.listdir(validation_apple_dir)))
print('Total validation orange images :', len(os.listdir(validation_orange_dir)))
# Out:
# Total training apple images : 10
# Total training orange images : 10
# Total validation apple images : 2
# Total validation orange images : 2

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_apple_pix = [os.path.join(train_apple_dir, fname)
                for fname in train_apple_fnames[ pic_index-8:pic_index]]

next_orange_pix = [os.path.join(train_orange_dir, fname)
                for fname in train_orange_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_apple_pix+next_orange_pix):
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off')

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
import tensorflow as tf


model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9470464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 20 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator, epochs = 50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 96ms/step - loss: 0.5724 - accuracy: 0.5500 - val_loss: 0.4869 - val_accuracy: 0.7500
# Epoch 2/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4646 - accuracy: 0.6500 - val_loss: 0.4815 - val_accuracy: 0.5000
# Epoch 3/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5153 - accuracy: 0.5000 - val_loss: 0.5084 - val_accuracy: 0.5000
# Epoch 4/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.5392 - accuracy: 0.6000 - val_loss: 0.3055 - val_accuracy: 1.0000
# Epoch 5/50
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3314 - accuracy: 0.8500 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 6/50
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1710 - accuracy: 0.9500 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 7/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0877 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 9/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 10/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 9.8011e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 7.4790e-04 - val_accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.3334e-04 - val_accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 4.0861e-04 - val_accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.0146e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 104ms/step - loss: 9.8923e-04 - accuracy: 1.0000 - val_loss: 2.3293e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 89ms/step - loss: 7.8249e-04 - accuracy: 1.0000 - val_loss: 1.7858e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 97ms/step - loss: 6.3118e-04 - accuracy: 1.0000 - val_loss: 1.4351e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 96ms/step - loss: 5.1593e-04 - accuracy: 1.0000 - val_loss: 1.1480e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 118ms/step - loss: 4.2631e-04 - accuracy: 1.0000 - val_loss: 9.3697e-05 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 76ms/step - loss: 3.5565e-04 - accuracy: 1.0000 - val_loss: 7.2864e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 94ms/step - loss: 2.9726e-04 - accuracy: 1.0000 - val_loss: 6.0793e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 74ms/step - loss: 2.4970e-04 - accuracy: 1.0000 - val_loss: 4.8145e-05 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 81ms/step - loss: 2.1210e-04 - accuracy: 1.0000 - val_loss: 4.1230e-05 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 79ms/step - loss: 1.8162e-04 - accuracy: 1.0000 - val_loss: 3.3362e-05 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 71ms/step - loss: 1.5619e-04 - accuracy: 1.0000 - val_loss: 2.8590e-05 - val_accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 69ms/step - loss: 1.3566e-04 - accuracy: 1.0000 - val_loss: 2.3676e-05 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1869e-04 - accuracy: 1.0000 - val_loss: 2.0660e-05 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0462e-04 - accuracy: 1.0000 - val_loss: 1.7390e-05 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 75ms/step - loss: 9.2830e-05 - accuracy: 1.0000 - val_loss: 1.5367e-05 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 73ms/step - loss: 8.2662e-05 - accuracy: 1.0000 - val_loss: 1.3120e-05 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 81ms/step - loss: 7.3963e-05 - accuracy: 1.0000 - val_loss: 1.1624e-05 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 78ms/step - loss: 6.6498e-05 - accuracy: 1.0000 - val_loss: 1.0064e-05 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 83ms/step - loss: 6.0016e-05 - accuracy: 1.0000 - val_loss: 8.9880e-06 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 91ms/step - loss: 5.4370e-05 - accuracy: 1.0000 - val_loss: 7.8616e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 144ms/step - loss: 4.9395e-05 - accuracy: 1.0000 - val_loss: 7.0725e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 111ms/step - loss: 4.5029e-05 - accuracy: 1.0000 - val_loss: 6.2328e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 83ms/step - loss: 4.1128e-05 - accuracy: 1.0000 - val_loss: 5.6368e-06 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 124ms/step - loss: 3.7646e-05 - accuracy: 1.0000 - val_loss: 5.0134e-06 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 95ms/step - loss: 3.4536e-05 - accuracy: 1.0000 - val_loss: 4.5281e-06 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 122ms/step - loss: 3.1736e-05 - accuracy: 1.0000 - val_loss: 4.0778e-06 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 128ms/step - loss: 2.9201e-05 - accuracy: 1.0000 - val_loss: 3.6522e-06 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 135ms/step - loss: 2.6925e-05 - accuracy: 1.0000 - val_loss: 3.3391e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 128ms/step - loss: 2.4871e-05 - accuracy: 1.0000 - val_loss: 2.9794e-06 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 112ms/step - loss: 2.2992e-05 - accuracy: 1.0000 - val_loss: 2.7404e-06 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 123ms/step - loss: 2.1299e-05 - accuracy: 1.0000 - val_loss: 2.4506e-06 - val_accuracy: 1.0000

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
#from google.colab import files
from keras.preprocessing import image
import os

test_dir = os.path.join('C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/test')

for fn in len(os.listdir(test_dir)):

    path='C:/Users/s8513/Desktop/동아리/사과, 오렌지 분류/apple_orange_filtered/test' + fn
    img=image.load_img(path, target_size=(150, 150))

    x=image.img_to_array(img)
    x=np.expand_dims(x, axis=0)
    images = np.vstack([x])

    classes = model.predict(images, batch_size=10)

    print(classes[0])

    if classes[0]>0:
        print(fn + " is a apple")
    else:
        print(fn + " is a orange")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2272\1633038322.py in <module>
#       1 import numpy as np
#       2 #from google.colab import files
# ----> 3 from keras.preprocessing import image
#       4 import os
#       5
#
# ~\anaconda3\envs\3week\lib\site-packages\keras\__init__.py in <module>
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 20 from keras import distribute
#      21 from keras import models
#      22 from keras.engine.input_layer import Input
#
# ~\anaconda3\envs\3week\lib\site-packages\keras\distribute\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.distribute import sidecar_evaluator
#
# ~\anaconda3\envs\3week\lib\site-packages\keras\distribute\sidecar_evaluator.py in <module>
#      20 from tensorflow.python.platform import tf_logging as logging
#      21 from tensorflow.python.util import deprecation
# ---> 22 from keras.optimizers.optimizer_experimental import (
#      23     optimizer as optimizer_experimental,
#      24 )
#
# ~\anaconda3\envs\3week\lib\site-packages\keras\optimizers\__init__.py in <module>
#      23
#      24 # Imports needed for deserialization.
# ---> 25 from keras import backend
#      26 from keras.optimizers.legacy import adadelta as adadelta_legacy
#      27 from keras.optimizers.legacy import adagrad as adagrad_legacy
#
# ~\anaconda3\envs\3week\lib\site-packages\keras\backend.py in <module>
#      30 import tensorflow.compat.v2 as tf
#      31
# ---> 32 from keras import backend_config
#      33 from keras.distribute import distribute_coordinator_utils as dc
#      34 from keras.engine import keras_tensor
#
# ~\anaconda3\envs\3week\lib\site-packages\keras\backend_config.py in <module>
#      31
#      32 @keras_export("keras.backend.epsilon")
# ---> 33 @tf.__internal__.dispatch.add_dispatch_support
#      34 def epsilon():
#      35     """Returns the value of the fuzz factor used in numeric expressions.
#
# AttributeError: module 'tensorflow.compat.v2' has no attribute '__internal__'
